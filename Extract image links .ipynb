# %%
import pandas as pd
import requests
import numpy as np
from PIL import Image
import ast
from ast import literal_eval

# %%
data = pd.read_csv('my_data.csv', index_col = 0)

# %%
def extract_images(name1, name2): # given a pair = name1, name2
    
    # we zip together all the image IDs and the responses and work on this list
    zip_ = list(zip(data['vg_image_id'], data['responses_v2'].apply(literal_eval)))
    
    lista = []
   
    for i in zip_: #for each (ID, responses) in ManyNames
        
        if len(list(i[1].keys())) > 1: # if the image has at least 2 types of response
            
            # we define as variables the first and the second response 
            response1 = list(i[1].keys())[0]
            response2 = list(i[1].keys())[1]
            
            # if the first response is name1 of our pair and the second response is name2 of our pair, or vice-versa
            # we append to a list the image ID, and the number of times name1 and name2 have been chosen as answers
            if response1 == name1 and response2 == name2 or response1 == name2 and response2 == name1:
                lista.append([i[0], i[1][name1], i[1][name2]])
    
    # we have now the image IDs we want to work on --> we extract their corresponding image link,
    # and generate a list with image ID, n. of times name1 has been chosen for that image, 
    # n. of times name2 has been chosen for that image, image link
    info = []
    for i in lista:            
        info.append([i[0], i[1], i[2], data.loc[data['vg_image_id'] == i[0], 'link_mn'].tolist()[0]])
    
    # we put it into a dataframe
    df = pd.DataFrame(info)
    df.columns = 'vg_image_id', name1, name2, 'link_mn'
    
    # we generate another column of the dataframe, with name1 - name2, to have our index:
    # if positive, it means that name 1 was the modal name
    # if negative, it means that name 2 was the modal name
    # if 0, it means that the 2 names had the same occurrences
    df["index "+name1+"-"+name2] = df[name1]-df[name2]
    
    #we sort the dataframe by the index
    df_sorted = df.sort_values(by= "index "+name1+"-"+name2, ascending = False)
    
    return df_sorted

# %%
# running this command, we'll have the dataframe
# the first cases with the highest indices are cases were name1 > name2
# the last cases with the lowest indices are cases were name2 > name1
extract_images("man", "tennis player")
# Out:
#     vg_image_id  man  tennis player  \
# 33      2360111   23              2
# 45      2368854   22              4
# 47      2369848   23              6
# 91      2417068   23              6
# 38      2362218   21              4
# 23      2346851   20              4
# 83      2410627   19              4
# 14      2332542   21              7
# 50      2372201   21              7
# 25      2349360   19              5
# 86      2411555   18              4
# 3       2316813   20              6
# 12      2329675   19              6
# 88      2414846   19              6
# 37      2362030   17              4
# 35      2360450   19              6
# 67      2388356   20              8
# 70      2391867   19              7
# 72      2395702   21              9
# 39      2363544   17              5
# 62      2380743   17              5
# 0        713476   19              7
# 20      2341998   19              7
# 18      2338795   17              5
# 55      2375126   18              7
# 48      2370144   18              7
# 57      2375523   16              5
# 89      2416817   20              9
# 75      2399858   18              7
# 80      2403044   16              5
# ..          ...  ...            ...
# 92      2417425   15             10
# 59      2375696   13              8
# 85      2411534   14              9
# 34      2360134   14              9
# 64      2382898   13              8
# 63      2381232   12              8
# 49      2371272   11              7
# 27      2351868   14             10
# 32      2359369   14             10
# 40      2365316   11              7
# 22      2345444   14             10
# 65      2385931   13              9
# 84      2411485   11              8
# 87      2412784   11              8
# 56      2375479   16             13
# 51      2372419   10              8
# 73      2398167    9              7
# 44      2367452   10              8
# 76      2400869   10              8
# 28      2354088   13             11
# 24      2347583    9              8
# 9       2325214    9              8
# 11      2327354    9              8
# 21      2343667   12             12
# 19      2339196    7              7
# 8       2323615    9             10
# 7       2322860   10             11
# 69      2391741    9             11
# 1       2315438    5              7
# 29      2355284    8             11
#
#                                               link_mn  index man-tennis player
# 33  http://object-naming-amore.upf.edu//2360111_78...                       21
# 45  http://object-naming-amore.upf.edu//2368854_34...                       18
# 47  http://object-naming-amore.upf.edu//2369848_60...                       17
# 91  http://object-naming-amore.upf.edu//2417068_28...                       17
# 38  http://object-naming-amore.upf.edu//2362218_37...                       17
# 23  http://object-naming-amore.upf.edu//2346851_20...                       16
# 83  http://object-naming-amore.upf.edu//2410627_21...                       15
# 14  http://object-naming-amore.upf.edu//2332542_30...                       14
# 50  http://object-naming-amore.upf.edu//2372201_26...                       14
# 25  http://object-naming-amore.upf.edu//2349360_22...                       14
# 86  http://object-naming-amore.upf.edu//2411555_31...                       14
# 3   http://object-naming-amore.upf.edu//2316813_34...                       14
# 12  http://object-naming-amore.upf.edu//2329675_27...                       13
# 88  http://object-naming-amore.upf.edu//2414846_15...                       13
# 37  http://object-naming-amore.upf.edu//2362030_26...                       13
# 35  http://object-naming-amore.upf.edu//2360450_23...                       13
# 67  http://object-naming-amore.upf.edu//2388356_67...                       12
# 70  http://object-naming-amore.upf.edu//2391867_48...                       12
# 72  http://object-naming-amore.upf.edu//2395702_12...                       12
# 39  http://object-naming-amore.upf.edu//2363544_19...                       12
# 62  http://object-naming-amore.upf.edu//2380743_38...                       12
# 0   http://object-naming-amore.upf.edu//713476_158...                       12
# 20  http://object-naming-amore.upf.edu//2341998_21...                       12
# 18  http://object-naming-amore.upf.edu//2338795_29...                       12
# 55  http://object-naming-amore.upf.edu//2375126_25...                       11
# 48  http://object-naming-amore.upf.edu//2370144_21...                       11
# 57  http://object-naming-amore.upf.edu//2375523_58...                       11
# 89  http://object-naming-amore.upf.edu//2416817_31...                       11
# 75  http://object-naming-amore.upf.edu//2399858_11...                       11
# 80  http://object-naming-amore.upf.edu//2403044_35...                       11
# ..                                                ...                      ...
# 92  http://object-naming-amore.upf.edu//2417425_37...                        5
# 59  http://object-naming-amore.upf.edu//2375696_17...                        5
# 85  http://object-naming-amore.upf.edu//2411534_30...                        5
# 34  http://object-naming-amore.upf.edu//2360134_78...                        5
# 64  http://object-naming-amore.upf.edu//2382898_53...                        5
# 63  http://object-naming-amore.upf.edu//2381232_70...                        4
# 49  http://object-naming-amore.upf.edu//2371272_19...                        4
# 27  http://object-naming-amore.upf.edu//2351868_85...                        4
# 32  http://object-naming-amore.upf.edu//2359369_21...                        4
# 40  http://object-naming-amore.upf.edu//2365316_26...                        4
# 22  http://object-naming-amore.upf.edu//2345444_10...                        4
# 65  http://object-naming-amore.upf.edu//2385931_38...                        4
# 84  http://object-naming-amore.upf.edu//2411485_31...                        3
# 87  http://object-naming-amore.upf.edu//2412784_36...                        3
# 56  http://object-naming-amore.upf.edu//2375479_58...                        3
# 51  http://object-naming-amore.upf.edu//2372419_59...                        2
# 73  http://object-naming-amore.upf.edu//2398167_42...                        2
# 44  http://object-naming-amore.upf.edu//2367452_62...                        2
# 76  http://object-naming-amore.upf.edu//2400869_11...                        2
# 28  http://object-naming-amore.upf.edu//2354088_26...                        2
# 24  http://object-naming-amore.upf.edu//2347583_17...                        1
# 9   http://object-naming-amore.upf.edu//2325214_98...                        1
# 11  http://object-naming-amore.upf.edu//2327354_35...                        1
# 21  http://object-naming-amore.upf.edu//2343667_36...                        0
# 19  http://object-naming-amore.upf.edu//2339196_31...                        0
# 8   http://object-naming-amore.upf.edu//2323615_28...                       -1
# 7   http://object-naming-amore.upf.edu//2322860_39...                       -1
# 69  http://object-naming-amore.upf.edu//2391741_12...                       -2
# 1   http://object-naming-amore.upf.edu//2315438_27...                       -2
# 29  http://object-naming-amore.upf.edu//2355284_18...                       -3
#
# [94 rows x 5 columns]

# %%
extract_images("surfer", "man")
# Out:
#     vg_image_id  surfer  man  \
# 0       2316639      24    6
# 51      2417219      22    7
# 16      2348496      21    7
# 4       2334533      18    5
# 41      2400315      19    6
# 9       2338643      22    9
# 22      2356481      18    5
# 29      2364184      20    8
# 21      2353377      21    9
# 12      2345446      23   11
# 45      2407350      20    8
# 33      2378412      19    8
# 25      2360026      20    9
# 8       2338328      16    5
# 17      2351599      18    8
# 46      2412009      19   10
# 36      2393402      21   13
# 42      2402714      17    9
# 39      2396443      18   10
# 49      2414130      15    9
# 28      2362637      14    9
# 18      2351744      15   11
# 48      2414078      13    9
# 5       2335862      11    8
# 13      2346546      14   11
# 32      2377951      14   11
# 43      2403330      14   12
# 2       2324739      17   15
# 50      2414939      12   10
# 7       2337655      10    9
# 24      2359396      17   16
# 10      2341357      10    9
# 40      2399291      16   16
# 1       2323565      11   11
# 37      2393599      14   15
# 26      2362191      12   13
# 35      2391926      16   17
# 14      2347799      11   12
# 34      2386815      13   15
# 44      2405603      11   13
# 6       2336480      10   13
# 30      2365564      12   16
# 19      2351845      11   16
# 3       2325502       9   17
# 27      2362620       8   17
# 23      2357429      10   19
# 47      2412739       9   19
# 52      2417801       9   22
# 11      2344948       7   22
# 31      2375037       4   21
# 38      2394130       5   23
# 15      2347874       4   26
# 20      2353227       2   26
#
#                                               link_mn  index surfer-man
# 0   http://object-naming-amore.upf.edu//2316639_34...                18
# 51  http://object-naming-amore.upf.edu//2417219_30...                15
# 16  http://object-naming-amore.upf.edu//2348496_36...                14
# 4   http://object-naming-amore.upf.edu//2334533_29...                13
# 41  http://object-naming-amore.upf.edu//2400315_11...                13
# 9   http://object-naming-amore.upf.edu//2338643_95...                13
# 22  http://object-naming-amore.upf.edu//2356481_31...                13
# 29  http://object-naming-amore.upf.edu//2364184_24...                12
# 21  http://object-naming-amore.upf.edu//2353377_84...                12
# 12  http://object-naming-amore.upf.edu//2345446_26...                12
# 45  http://object-naming-amore.upf.edu//2407350_36...                12
# 33  http://object-naming-amore.upf.edu//2378412_55...                11
# 25  http://object-naming-amore.upf.edu//2360026_17...                11
# 8   http://object-naming-amore.upf.edu//2338328_32...                11
# 17  http://object-naming-amore.upf.edu//2351599_17...                10
# 46  http://object-naming-amore.upf.edu//2412009_20...                 9
# 36  http://object-naming-amore.upf.edu//2393402_38...                 8
# 42  http://object-naming-amore.upf.edu//2402714_38...                 8
# 39  http://object-naming-amore.upf.edu//2396443_44...                 8
# 49  http://object-naming-amore.upf.edu//2414130_15...                 6
# 28  http://object-naming-amore.upf.edu//2362637_35...                 5
# 18  http://object-naming-amore.upf.edu//2351744_23...                 4
# 48  http://object-naming-amore.upf.edu//2414078_16...                 4
# 5   http://object-naming-amore.upf.edu//2335862_27...                 3
# 13  http://object-naming-amore.upf.edu//2346546_17...                 3
# 32  http://object-naming-amore.upf.edu//2377951_71...                 3
# 43  http://object-naming-amore.upf.edu//2403330_35...                 2
# 2   http://object-naming-amore.upf.edu//2324739_30...                 2
# 50  http://object-naming-amore.upf.edu//2414939_14...                 2
# 7   http://object-naming-amore.upf.edu//2337655_20...                 1
# 24  http://object-naming-amore.upf.edu//2359396_35...                 1
# 10  http://object-naming-amore.upf.edu//2341357_36...                 1
# 40  http://object-naming-amore.upf.edu//2399291_41...                 0
# 1   http://object-naming-amore.upf.edu//2323565_10...                 0
# 37  http://object-naming-amore.upf.edu//2393599_12...                -1
# 26  http://object-naming-amore.upf.edu//2362191_77...                -1
# 35  http://object-naming-amore.upf.edu//2391926_12...                -1
# 14  http://object-naming-amore.upf.edu//2347799_88...                -1
# 34  http://object-naming-amore.upf.edu//2386815_51...                -2
# 44  http://object-naming-amore.upf.edu//2405603_33...                -2
# 6   http://object-naming-amore.upf.edu//2336480_22...                -3
# 30  http://object-naming-amore.upf.edu//2365564_63...                -4
# 19  http://object-naming-amore.upf.edu//2351845_20...                -5
# 3   http://object-naming-amore.upf.edu//2325502_30...                -8
# 27  http://object-naming-amore.upf.edu//2362620_32...                -9
# 23  http://object-naming-amore.upf.edu//2357429_26...                -9
# 47  http://object-naming-amore.upf.edu//2412739_18...               -10
# 52  http://object-naming-amore.upf.edu//2417801_28...               -13
# 11  http://object-naming-amore.upf.edu//2344948_91...               -15
# 31  http://object-naming-amore.upf.edu//2375037_58...               -17
# 38  http://object-naming-amore.upf.edu//2394130_46...               -18
# 15  http://object-naming-amore.upf.edu//2347874_88...               -22
# 20  http://object-naming-amore.upf.edu//2353227_31...               -24
